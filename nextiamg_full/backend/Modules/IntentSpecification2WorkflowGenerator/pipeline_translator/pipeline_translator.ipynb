# %%
import os
import tempfile
import zipfile
import shutil
import xml.etree.ElementTree as ET
from datetime import datetime, timezone
from typing import Tuple, Dict, List

from tqdm.notebook import tqdm

from common import *

# %%
def load_workflow(path: str) -> Graph:
    graph = get_graph()
    graph.parse(path, format='turtle')
    return graph

# %%
def get_workflow_steps(graph: Graph) -> List[URIRef]:
    steps = list(graph.subjects(RDF.type, dtbox.Step))
    return steps

# %%
def get_base_node_config():
    root = ET.Element('config', {'xmlns': 'http://www.knime.org/2008/09/XMLConfig',
                                 'xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                 'xsi:schemaLocation': 'http://www.knime.org/2008/09/XMLConfig http://www.knime.org/XMLConfig_2008_09.xsd',
                                 'key': 'settings.xml',
                                 })

    ET.SubElement(root, 'entry', {'key': 'node_file', 'type': 'xstring', 'value': 'settings.xml'})
    ET.SubElement(root, 'entry', {'key': 'customDescription', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry', {'key': 'state', 'type': 'xstring', 'value': 'CONFIGURED'})
    ET.SubElement(root, 'entry', {'key': 'hasContent', 'type': 'xboolean', 'value': 'false'})
    ET.SubElement(root, 'entry', {'key': 'isInactive', 'type': 'xboolean', 'value': 'false'})
    ET.SubElement(root, 'config', {'key': 'factory_settings'})
    ET.SubElement(root, 'entry', {'key': 'node-feature-name', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry',
                  {'key': 'node-feature-symbolic-name', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry', {'key': 'node-feature-vendor', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry', {'key': 'node-feature-version', 'type': 'xstring', 'value': '0.0.0'})

    ET.SubElement(root, 'config', {'key': 'flow_stack'})

    return ET.ElementTree(root)

# %%
def get_step_component_implementation(ontology: Graph, workflow_graph: Graph, step: URIRef) -> Tuple[URIRef, URIRef]:
    component = next(workflow_graph.objects(step, dtbox.runs, True))
    implementation = next(ontology.objects(component, dtbox.hasImplementation, True))
    return component, implementation

# %%
def get_knime_properties(ontology: Graph, implementation: URIRef) -> Dict[str, str]:
    results = {}
    for p, o in ontology.predicate_objects(implementation):
        if p.fragment.startswith('knime'):
            results[p.fragment[6:]] = o.value
    return results

# %%
def get_number_of_output_ports(ontology: Graph, workflow_graph: Graph, step: URIRef) -> int:
    _, implementation = get_step_component_implementation(ontology, workflow_graph, step)
    return sum(1 for _ in ontology.objects(implementation, dtbox.specifiesOutput))

# %%
def get_step_parameters(ontology: Graph, workflow_graph: Graph, step: URIRef) -> List[Tuple[str, str, str, URIRef]]:
    param_values = list(workflow_graph.objects(step, dtbox.hasParameterValue))
    parameters = [next(workflow_graph.objects(pv, dtbox.forParameter, True)) for pv in param_values]
    values = [next(workflow_graph.objects(pv, dtbox.has_value, True)).value for pv in param_values]
    keys = [next(ontology.objects(p, dtbox.knime_key, True)).value for p in parameters]
    paths = [next(ontology.objects(p, dtbox.knime_path, True)).value for p in parameters]
    types = [next(ontology.objects(p, dtbox.hasDatatype, True)) for p in parameters]
    return list(zip(keys, values, paths, types))

# %%
def update_hierarchy(path_elements: Dict[str, ET.Element], path: str) -> Dict[str, ET.Element]:
    if path in path_elements:
        return path_elements
    levels = path.split('/')
    current_path = ''
    previous = None
    for level in levels:
        current_path += level
        if current_path not in path_elements:
            path_elements[current_path] = ET.SubElement(previous, 'config', {'key': level})
        previous = path_elements[current_path]
        current_path += '/'


def get_step_model_config(ontology: Graph, workflow_graph: Graph, step: URIRef) -> ET.Element:
    path_elements = {
        'model': ET.Element('config', {'key': 'model'}),
    }

    types = {
        XSD.string: 'xstring',
        XSD.int: 'xint',
        XSD.integer: 'xint',
        XSD.long: 'xlong',
        XSD.float: 'xdouble',
        XSD.double: 'xdouble',
        XSD.boolean: 'xboolean',
    }

    parameters = get_step_parameters(ontology, workflow_graph, step)
    for key, value, path, value_type in parameters:
        update_hierarchy(path_elements, path)
        base = path_elements[path]
        if value_type == RDF.List:
            values = value.split(',')
            config = ET.SubElement(base, 'config', {'key': key})
            ET.SubElement(config, 'entry', {'key': 'array-size', 'type': 'xint', 'value': str(len(values))})
            for i, v in enumerate(values):
                ET.SubElement(config, 'entry', {'key': str(i), 'type': 'xstring', 'value': v})
        elif key == '$$SKIP$$':
            continue
        else:
            if value is None or (isinstance(value, str) and value.lower() == 'none'):
                ET.SubElement(base, 'entry', {'key': key, 'type': types[value_type], 'value': '', 'isnull': 'true'})
            else:
                ET.SubElement(base, 'entry', {'key': key, 'type': types[value_type], 'value': str(value)})

    return path_elements['model']

# %%
def create_step_file(ontology: Graph, workflow_graph: Graph, step: URIRef, folder, iterator: int) -> str:
    tree = get_base_node_config()
    root = tree.getroot()

    component, implementation = get_step_component_implementation(ontology, workflow_graph, step)
    properties = get_knime_properties(ontology, implementation)

    for key, value in properties.items():
        ET.SubElement(root, 'entry', {'key': key, 'type': 'xstring', 'value': value})

    path_name = properties["node-name"].replace('(', '_').replace(')', '_')

    model = get_step_model_config(ontology, workflow_graph, step)
    root.append(model)

    filestores = ET.SubElement(root, 'config', {'key': 'filestores'})
    ET.SubElement(filestores, 'entry', {'key': 'file_store_location', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(filestores, 'entry', {'key': 'file_store_id', 'type': 'xstring', 'isnull': 'true', 'value': ''})

    internal_node_subsettings = ET.SubElement(root, 'config', {'key': 'internal_node_subsettings'})
    ET.SubElement(internal_node_subsettings, 'entry',
                  {'key': 'memory_policy', 'type': 'xstring', 'value': 'CacheSmallInMemory'})

    ports = ET.SubElement(root, 'config', {'key': 'ports'})
    for i in range(get_number_of_output_ports(ontology, workflow_graph, step)):
        port = ET.SubElement(ports, 'config', {'key': f'port_{i + 1}'})
        ET.SubElement(port, 'entry', {'key': 'index', 'type': 'xint', 'value': str(i + 1)})
        ET.SubElement(port, 'entry', {'key': 'port_dir_location', 'type': 'xstring', 'isnull': 'true', 'value': ''})

    subfolder_name = f'{path_name} (#{iterator})'
    subfolder = os.path.join(folder, subfolder_name)
    os.mkdir(subfolder)

    ET.indent(tree, space='    ')
    tree.write(os.path.join(subfolder, 'settings.xml'), encoding='utf-8', xml_declaration=True)
    return subfolder_name

# %%
def get_workflow_intent_name(workflow_graph: Graph) -> str:
    return next(workflow_graph.subjects(RDF.type, dtbox.Intent, True)).fragment


def get_workflow_intent_number(workflow_graph: Graph) -> int:
    return int(next(workflow_graph.subjects(RDF.type, dtbox.Workflow, True)).fragment.split('_')[1])

# %%
def create_workflow_metadata_file(workflow_graph: Graph, folder: str) -> None:
    author = 'Diviloper'
    date = datetime.today().strftime('%d/%m/%Y')
    workflow_name = next(workflow_graph.subjects(RDF.type, dtbox.Workflow, True)).fragment
    title = f'{get_workflow_intent_name(workflow_graph)} (Workflow {get_workflow_intent_number(workflow_graph)})'
    description = f'This workflow was automatically created from the logical workflow {workflow_name}.'
    url = 'ExtremeXP https://extremexp.eu/'
    tags = 'model training, training, testing'
    template = f'''<?xml version="1.0" encoding="UTF-8"?>
<KNIMEMetaInfo nrOfElements="3">
    <element form="text" read-only="false" name="Author">{author}</element>
    <element form="date" name="Creation Date" read-only="false">{date}</element>
    <element form="multiline" name="Comments" read-only="false">{title}&#13;
&#13;
{description}&#13;
&#13;
URL: {url}&#13;
TAG: {tags}&#13;
</element>
</KNIMEMetaInfo>
'''
    with open(os.path.join(folder, 'workflowset.meta'), 'w') as f:
        f.write(template)

# %%
def get_nodes_config(step_paths: List[str]) -> ET.Element:
    root = ET.Element('config', {'key': 'nodes'})
    for i, step in enumerate(step_paths):
        node_cofig = ET.SubElement(root, 'config', {'key': f'node_{i}'})
        ET.SubElement(node_cofig, 'entry', {'key': 'id', 'type': 'xint', 'value': str(i)})
        ET.SubElement(node_cofig, 'entry', {'key': 'node_settings_file', 'type': 'xstring',
                                            'value': f'{step}/settings.xml'})
        ET.SubElement(node_cofig, 'entry', {'key': 'node_is_meta', 'type': 'xboolean', 'value': 'false'})
        ET.SubElement(node_cofig, 'entry', {'key': 'node_type', 'type': 'xstring', 'value': 'NativeNode'})
        ET.SubElement(node_cofig, 'entry', {'key': 'ui_classname', 'type': 'xstring',
                                            'value': 'org.knime.core.node.workflow.NodeUIInformation'})
        ui_settings = ET.SubElement(node_cofig, 'config', {'key': 'ui_settings'})
        bounds = ET.SubElement(ui_settings, 'config', {'key': 'extrainfo.node.bounds'})

        applier = any(x in step.lower() for x in ['appl', 'predictor'])
        ET.SubElement(bounds, 'entry', {'key': 'array-size', 'type': 'xint', 'value': '4'})
        ET.SubElement(bounds, 'entry', {'key': '0', 'type': 'xint', 'value': str((i + 1) * 150)})  # x
        ET.SubElement(bounds, 'entry', {'key': '1', 'type': 'xint', 'value': '400' if applier else '200'})  # y
        ET.SubElement(bounds, 'entry', {'key': '2', 'type': 'xint', 'value': '75'})  # width
        ET.SubElement(bounds, 'entry', {'key': '3', 'type': 'xint', 'value': '80'})  # height

    return root

# %%
def get_workflow_connections(workflow_graph: Graph) -> List[Tuple[URIRef, URIRef, URIRef, URIRef]]:
    query = f'''
    PREFIX dtbox: <{dtbox}>
    SELECT ?source ?destination ?sourcePort ?destinationPort
    WHERE {{
        # ?source a dtbox:Step ;
                dtbox:followedBy ?destination ;
                dtbox:hasOutput ?output .
        # ?output dtbox:has_position ?sourcePort ;
                dtbox:hasData ?link .
        # ?destination a dtbox:Step ;
                    dtbox:hasInput ?input .
        # ?input dtbox:has_position ?destinationPort ;
                dtbox:hasData ?link .
    }}
    '''
    results = workflow_graph.query(query).bindings
    return [(r['source'], r['destination'], r['sourcePort'], r['destinationPort']) for r in results]

# %%
def get_connections_config(workflow_graph: Graph, steps: List[URIRef]) -> ET.Element:
    root = ET.Element('config', {'key': 'connections'})
    connections = get_workflow_connections(workflow_graph)
    for i, (source, destination, source_port, destination_port) in enumerate(connections):
        connection_config = ET.SubElement(root, 'config', {'key': f'connection_{i}'})
        ET.SubElement(connection_config, 'entry',
                      {'key': 'sourceID', 'type': 'xint', 'value': str(steps.index(source))})
        ET.SubElement(connection_config, 'entry', {'key': 'sourcePort', 'type': 'xint', 'value': str(source_port + 1)})
        ET.SubElement(connection_config, 'entry',
                      {'key': 'destID', 'type': 'xint', 'value': str(steps.index(destination))})
        ET.SubElement(connection_config, 'entry',
                      {'key': 'destPort', 'type': 'xint', 'value': str(destination_port + 1)})
        ET.SubElement(connection_config, 'entry', {'key': 'ui_classname', 'type': 'xstring',
                                                   'value': 'org.knime.core.node.workflow.ConnectionUIInformation'})
        ui_settings = ET.SubElement(connection_config, 'config', {'key': 'ui_settings'})
        ET.SubElement(ui_settings, 'entry', {'key': 'extrainfo.conn.bendpoints_size', 'type': 'xint', 'value': '0'})
    return root

# %%
def get_author_config() -> ET.Element:
    root = ET.Element('config', {'key': 'authorInformation'})
    ET.SubElement(root, 'entry', {'key': 'authored-by', 'type': 'xstring', 'value': 'Diviloper'})
    ET.SubElement(root, 'entry', {'key': 'authored-when', 'type': 'xstring',
                                  'value': datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S %z')})
    ET.SubElement(root, 'entry', {'key': 'lastEdited-by', 'type': 'xstring', 'value': 'Diviloper'})
    ET.SubElement(root, 'entry', {'key': 'lastEdited-when', 'type': 'xstring',
                                  'value': datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S %z')})
    return root

# %%
def create_workflow_file(workflow_graph: Graph, steps: List[URIRef], step_paths: List[str],
                         folder: str) -> None:
    node_config = get_nodes_config(step_paths)
    connections_config = get_connections_config(workflow_graph, steps)
    author_config = get_author_config()

    root = ET.Element('config', {'xmlns': 'http://www.knime.org/2008/09/XMLConfig',
                                 'xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                 'xsi:schemaLocation': 'http://www.knime.org/2008/09/XMLConfig http://www.knime.org/XMLConfig_2008_09.xsd',
                                 'key': 'workflow.knime'})

    ET.SubElement(root, 'entry', {'key': 'created_by', 'type': 'xstring', 'value': '4.7.3.v202305100921'})
    ET.SubElement(root, 'entry', {'key': 'created_by_nightly', 'type': 'xboolean', 'value': 'false'})
    ET.SubElement(root, 'entry', {'key': 'version', 'type': 'xstring', 'value': '4.1.0'})
    ET.SubElement(root, 'entry', {'key': 'name', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry', {'key': 'customDescription', 'type': 'xstring', 'isnull': 'true', 'value': ''})
    ET.SubElement(root, 'entry', {'key': 'state', 'type': 'xstring', 'value': 'IDLE'})
    ET.SubElement(root, 'config', {'key': 'workflow_credentials'})

    root.append(node_config)
    root.append(connections_config)
    root.append(author_config)

    tree = ET.ElementTree(root)
    ET.indent(tree, space='    ')
    tree.write(os.path.join(folder, 'workflow.knime'), encoding='UTF-8', xml_declaration=True)

# %%
def package_workflow(folder: str, destination: str) -> None:
    with zipfile.ZipFile(destination, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder):
            for file in files:
                file_path = os.path.join(root, file)
                archive_path = os.path.relpath(file_path, folder)
                zipf.write(file_path, arcname=os.path.join(os.path.basename(folder), archive_path))

# %%
def translate_graph(ontology: Graph, source_path: str, destination_path: str, keep_folder=False) -> None:
    print('Creating new workflow')

    print('\tCreating temp folder: ', end='')
    temp_folder = tempfile.mkdtemp()
    print(temp_folder)

    print('\tLoading workflow:', end=' ')
    graph = load_workflow(source_path)
    print(next(graph.subjects(RDF.type, dtbox.Workflow, True)).fragment)

    print('\tCreating workflow metadata file')
    create_workflow_metadata_file(graph, temp_folder)

    print('\tBuilding steps')
    steps = get_workflow_steps(graph)
    step_paths = []
    for i, step in enumerate(steps):
        step_paths.append(create_step_file(ontology, graph, step, temp_folder, i))

    print('\tCreating workflow file')
    create_workflow_file(graph, steps, step_paths, temp_folder)

    print('\tCreating zip file')
    package_workflow(temp_folder, destination_path)

    if keep_folder:
        print('\tCopying temp folder')
        shutil.copytree(temp_folder, destination_path[:-4])

    print('\tRemoving temp folder')
    shutil.rmtree(temp_folder)
    print('Done')
    print('-' * 50)

# %%
def translate_graph_folder(ontology: Graph, source_folder: str, destination_folder: str, keep_folder=False) -> None:
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    assert os.path.exists(source_folder)

    workflows = [f for f in os.listdir(source_folder) if f.endswith('.ttl')]
    for workflow in tqdm(workflows):
        source_path = os.path.join(source_folder, workflow)
        destination_path = os.path.join(destination_folder, workflow[:-4] + '.knwf')
        translate_graph(ontology, source_path, destination_path, keep_folder)

# %%
session = '2023-07-16 17-50-43'
source_folder = f'../pipeline_generator/workflows/{session}'
destination_folder = f'./workflows/{session}'
translate_graph_folder(get_ontology_graph(), source_folder, destination_folder, keep_folder=True)
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp668yrp4_
# 	Loading workflow: workflow_0_DescriptionIntent_78dc958a_6bba_4263_ac51_064b130629b3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpasqzrp2m
# 	Loading workflow: workflow_10_DescriptionIntent_422ee380_a60d_47d1_b4da_783120d9e058
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpoc5s_9wa
# 	Loading workflow: workflow_11_DescriptionIntent_4b11639f_1f04_4393_8745_f0603067407e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp0g2mcw9u
# 	Loading workflow: workflow_12_DescriptionIntent_eb6e9a71_7a0d_4c52_b14a_942ab0289aa8
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp5zvi0jx5
# 	Loading workflow: workflow_13_DescriptionIntent_6d3004cc_f379_4383_bafc_f1181e24319c
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp0yniit73
# 	Loading workflow: workflow_14_DescriptionIntent_d501a5d7_1b37_4310_aadf_04156ef8d90a
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpfl39ifwz
# 	Loading workflow: workflow_15_DescriptionIntent_7093dea8_7b33_4fd3_b57f_6e6ffa13af45
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp57pxr3yx
# 	Loading workflow: workflow_16_DescriptionIntent_6a2dc97e_b452_4d94_b953_16d690073b28
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp73hclfbb
# 	Loading workflow: workflow_17_DescriptionIntent_6f0d950e_2eb8_4be6_9d41_450b9e7429e3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp91jp5l98
# 	Loading workflow: workflow_18_DescriptionIntent_29e44811_8820_4f4f_a24d_0f130e9cf853
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpco6raaq8
# 	Loading workflow: workflow_19_DescriptionIntent_8272cc7c_79e4_4392_93b9_6e4e5f60a2ee
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp03tya_ph
# 	Loading workflow: workflow_1_DescriptionIntent_46439c82_9656_4faf_9523_b5154ca6f4fc
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmphxgsmrbi
# 	Loading workflow: workflow_20_DescriptionIntent_5128a3b2_bd54_4a14_b4ed_805ca4581ca4
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpmih4j0hd
# 	Loading workflow: workflow_21_DescriptionIntent_623f6c2b_b10e_405c_922c_c62405e8c3d9
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp_b269g80
# 	Loading workflow: workflow_22_DescriptionIntent_37b8b4e4_f21b_439a_8c69_fbc8cb039ec6
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpa3597hfi
# 	Loading workflow: workflow_23_DescriptionIntent_0f95b666_a544_476d_ba3f_3c280bf878d7
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmprohr951e
# 	Loading workflow: workflow_24_DescriptionIntent_5b41870b_12d1_45f6_9ec6_0aa3ff5d6e78
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmprrmvfvt9
# 	Loading workflow: workflow_25_DescriptionIntent_96217e95_554e_46b8_b594_3810f36952f2
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpx4fkte1q
# 	Loading workflow: workflow_26_DescriptionIntent_7894518e_b464_4c33_8961_5d816fc80b9a
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpawmtttys
# 	Loading workflow: workflow_27_DescriptionIntent_fdece856_ccec_4fbc_972a_e75d11ee0018
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpzfghz5er
# 	Loading workflow: workflow_28_DescriptionIntent_f7c29314_2124_41f2_8eeb_4d39b49687f2
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpxpmm1ldn
# 	Loading workflow: workflow_29_DescriptionIntent_12df779b_60c6_49d3_b7e0_76431d89e757
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp6ai7bj_8
# 	Loading workflow: workflow_2_DescriptionIntent_27702bbb_a47e_4d05_90ca_cca4a3c624b3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp8t5thju5
# 	Loading workflow: workflow_30_DescriptionIntent_623620cb_03ee_4117_835e_ff2080e5b13e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpuhowtwyn
# 	Loading workflow: workflow_31_DescriptionIntent_58c349fc_3fc7_4dd0_a62a_ef82b7b4b338
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp1rj23g4i
# 	Loading workflow: workflow_32_DescriptionIntent_66ecc84c_f7d8_4871_818b_6d588efec1ee
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpzdzlunu4
# 	Loading workflow: workflow_33_DescriptionIntent_768fa2e8_8891_44c4_a9aa_01b7b6b329e3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpw9bwoewm
# 	Loading workflow: workflow_34_DescriptionIntent_3b3cf27d_edd3_4ea1_ba0b_fbaf6ede075e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp9h90ay34
# 	Loading workflow: workflow_35_DescriptionIntent_82f9b4ec_a14b_491b_be55_b94112460b43
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpyxarh15l
# 	Loading workflow: workflow_36_DescriptionIntent_e77231f8_828f_4be2_a82b_48b5b2292670
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp7tunlzc0
# 	Loading workflow: workflow_37_DescriptionIntent_5430a644_e498_47f8_ae89_bb2d6a1d2778
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmptgxenhtm
# 	Loading workflow: workflow_38_DescriptionIntent_bf2e9913_1999_4dd0_b36e_becbf2e7e97e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp7q_uhtt6
# 	Loading workflow: workflow_39_DescriptionIntent_15398e58_d09a_4dac_81d1_33f7b5a90cd2
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp2yfoi1k4
# 	Loading workflow: workflow_3_DescriptionIntent_465b5be6_8492_44b4_ac91_2c1e651c0f9b
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpsswetrc1
# 	Loading workflow: workflow_40_DescriptionIntent_579a970d_667a_45b8_a551_15726c57755e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpzpq0s0yy
# 	Loading workflow: workflow_41_DescriptionIntent_0a7d5379_0e6c_47cd_b866_ccfbf72186f0
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpxcc0v6xv
# 	Loading workflow: workflow_42_DescriptionIntent_20a1f8ee_86f4_4d42_bb7d_e070287e5648
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpy9spukfy
# 	Loading workflow: workflow_43_DescriptionIntent_75398f23_3116_4668_8833_410813216064
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpaintlly6
# 	Loading workflow: workflow_44_DescriptionIntent_48205b6c_2771_45a6_b22d_94359087a724
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp0__mko3v
# 	Loading workflow: workflow_45_DescriptionIntent_fc065282_c950_4ac4_b672_ce1f74fd2a22
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp45emet43
# 	Loading workflow: workflow_46_DescriptionIntent_788a2560_83bb_4793_906b_d247f231e02e
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpbwpx_g5b
# 	Loading workflow: workflow_47_DescriptionIntent_61f4c035_fe5c_4e85_8594_1a9ff68c3421
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp6k1rhxd5
# 	Loading workflow: workflow_48_DescriptionIntent_a99d9983_1d49_434c_8dcf_685dc64df2c9
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpmg5o9e_7
# 	Loading workflow: workflow_49_DescriptionIntent_f90c214d_27c4_4e6a_9a21_7943966b1646
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpvk_54r4u
# 	Loading workflow: workflow_4_DescriptionIntent_1078a5f5_d58e_4ed3_a746_02a857d19d4a
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpqo3re8gi
# 	Loading workflow: workflow_50_DescriptionIntent_d72d3fdc_dc5e_4c12_a0f6_2e6354913498
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpsbsoanq5
# 	Loading workflow: workflow_51_DescriptionIntent_16ca1719_a385_4dc4_920a_f89c90291c2f
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpvco2iciu
# 	Loading workflow: workflow_52_DescriptionIntent_9b2fde61_ca95_4e39_b128_b760cd38e840
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpf78ns8de
# 	Loading workflow: workflow_53_DescriptionIntent_0f1d7021_876e_4407_a9b0_ce05531aa02a
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpctjpummr
# 	Loading workflow: workflow_54_DescriptionIntent_6ee99998_babe_4225_b2bd_c331f370ccd8
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmppbj4g9j0
# 	Loading workflow: workflow_55_DescriptionIntent_faee53f0_7840_4b8d_836a_4701ca65bae6
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpveoz9924
# 	Loading workflow: workflow_56_DescriptionIntent_5477de9f_30f5_451a_ad31_026ac62df831
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp8wdx4w_5
# 	Loading workflow: workflow_57_DescriptionIntent_908658b1_e828_4914_aa20_330ad3b27c09
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp8euq2i7q
# 	Loading workflow: workflow_58_DescriptionIntent_d174062e_b9e5_4225_b31c_bf0beadb5cc2
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpmaqol5dm
# 	Loading workflow: workflow_59_DescriptionIntent_3eddb065_21ef_4321_98ac_e81babeeb8d9
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp4710j12h
# 	Loading workflow: workflow_5_DescriptionIntent_201c5021_aee7_43ab_ab4c_2dd958f068af
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpgbemkn04
# 	Loading workflow: workflow_60_DescriptionIntent_8838c82c_cfb1_4678_8b11_ce37e495fc83
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpgs9y47f1
# 	Loading workflow: workflow_61_DescriptionIntent_c1d8b4cf_7fdd_4828_8a8b_7ab1929008ef
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpchz_kz24
# 	Loading workflow: workflow_62_DescriptionIntent_9edaf539_2714_49dc_b2cc_86c66fa0b265
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpvbjv0fxu
# 	Loading workflow: workflow_63_DescriptionIntent_e4ffe234_bf19_4771_8fa1_c2c597385e5d
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpjv9ayh53
# 	Loading workflow: workflow_64_DescriptionIntent_e443d0e7_e9f7_4e37_a331_186e6dd132c2
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpsr00eabz
# 	Loading workflow: workflow_65_DescriptionIntent_b06890aa_3faa_4cbb_92b9_7418d179d988
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp4oybg23p
# 	Loading workflow: workflow_66_DescriptionIntent_123e80fd_65d3_4c9c_bac6_157b11f5c3b3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpu5elt6vi
# 	Loading workflow: workflow_67_DescriptionIntent_2be41fde_8585_444f_a91a_cf1fd8f0bbd3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpg9oxqwb0
# 	Loading workflow: workflow_68_DescriptionIntent_16e39f6c_be48_47c7_8724_e2d432ec1599
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpvv8ev4v6
# 	Loading workflow: workflow_69_DescriptionIntent_719c4381_b320_418b_94c8_8c23fb15695f
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpap1xpm49
# 	Loading workflow: workflow_6_DescriptionIntent_44434a83_96c5_4e57_8925_787d77872100
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpdezatv_m
# 	Loading workflow: workflow_70_DescriptionIntent_5f912356_cf65_4dea_ba3b_8153c2431be6
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpuvlasdit
# 	Loading workflow: workflow_71_DescriptionIntent_1e63388a_d70b_446d_8fee_76ed0c397c01
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpkl4qrg3i
# 	Loading workflow: workflow_72_DescriptionIntent_6ce91fb4_5adf_4931_bab1_2504eff2cfd3
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpvfvaj8s_
# 	Loading workflow: workflow_73_DescriptionIntent_86fafc07_a645_4e95_96ad_d70c16b8d03b
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmps0e1ngqr
# 	Loading workflow: workflow_74_DescriptionIntent_5c31814e_d77e_424b_a790_ab158ee3beeb
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp2qar55w3
# 	Loading workflow: workflow_75_DescriptionIntent_7202b6ce_eac6_444c_af87_44c047026200
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpaxtqfaq9
# 	Loading workflow: workflow_7_DescriptionIntent_6d02b39b_7485_4895_af06_95c7b9400317
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmp20kj_76y
# 	Loading workflow: workflow_8_DescriptionIntent_e9ec8261_90c4_4b45_ab3d_5028c206aa6c
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
# Creating new workflow
# 	Creating temp folder: C:\Users\Victor\AppData\Local\Temp\tmpd8u9tzk1
# 	Loading workflow: workflow_9_DescriptionIntent_c8bd7d85_8087_4a1c_96f0_503028cef360
# 	Creating workflow metadata file
# 	Building steps
# 	Creating workflow file
# 	Creating zip file
# 	Copying temp folder
# 	Removing temp folder
# Done
# --------------------------------------------------
